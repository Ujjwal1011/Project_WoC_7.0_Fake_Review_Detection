# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
def is_amazon_url(url):
    # Regular expression to check if the URL is an Amazon product URL
    amazon_pattern = r"(https?://)?(www\.)?amazon\.(com|in|co\.uk|de|ca|fr|co\.jp|it|es|nl|com\.mx|com\.au|com\.br|ae|sg|sa)/.*"
    return bool(re.match(amazon_pattern, url))

# %%
def scrape_amazon_reviews_and_category(product_url):
    if not is_amazon_url(url):
        raise ValueError("The provided URL is not an Amazon product URL.")
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept-Encoding': 'gzip, deflate, br',
        'Connection': 'keep-alive',
        'Referer': 'https://www.google.com/',
        'DNT': '1',  
        'Upgrade-Insecure-Requests': '1',
    }
    
    response = requests.get(product_url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extract Category
        category_section = soup.select_one('#wayfinding-breadcrumbs_container')  # Modify selector based on actual structure
        if category_section:
            categories = [cat.text.strip() for cat in category_section.select('a')]
        else:
            categories = []
        
        # Extract Reviews
        reviews = []
        for review in soup.select('.review'):
            title = review.select_one('.review-title').text.strip() if review.select_one('.review-title') else None
            content = review.select_one('.review-text').text.strip() if review.select_one('.review-text') else None
            rating = review.select_one('.review-rating').text.strip() if review.select_one('.review-rating') else None
            
            reviews.append({
                "title": title,
                "content": content,
                "rating": rating,
            })
        
        return {
            "categories": categories,
            "reviews": reviews,
        }
    else:
        print("Failed to fetch the page. Status Code:", response.status_code)
        return {}

# %%
# Example usage
try:
    url = input("Enter the Amazon URL: ")  # Replace with an actual product URL
    result = scrape_amazon_reviews_and_category(url)

    # Print extracted data
    print("\nCategories:")
    print(" > ".join(result['categories']))
    print("\nReviews:")
    for review in result['reviews']:
        print("Title:", review['title'])
        print("Rating:", review['rating'])
        print("Content:", review['content'])
        print("-" * 80)
except ValueError as e:
    print(e)
# Out:
# Categories:
# Clothing, Shoes & Jewelry > Men > Clothing > Shirts > Button-Down Shirts
#
# Reviews:
# Title: 5.0 out of 5 stars
# Comfortable and Versatile
# Rating: 5.0 out of 5 stars
# Content: It is super comfy. It can be casual comfort or it can be worn as a semi-formal top. It looks incredible. It fits great. It is light and breathable. Great material. Soft and gentle to the skin. Great quality, I will be buying more in different colors. Worth the money.
# Read more
# --------------------------------------------------------------------------------
# Title: 5.0 out of 5 stars
# Great fit and look!
# Rating: 5.0 out of 5 stars
# Content: The shirt is very nice quality, comfortable, and true to size. Looks great!
# Read more
# --------------------------------------------------------------------------------
# Title: 4.0 out of 5 stars
# Purchased for my son
# Rating: 4.0 out of 5 stars
# Content: He likes the pointelle knit to add interest to the shirt (not just flat or rib knit). The fit runs slightly large but he likes a looser fit. The button holes are somewhat loose so I suggest washing this shirt in a knit bag for delicates to help stop the button holes from stretching more. The fabric is not natural fiber but it's relatively soft and with the pointelle (more open) knit it is breathable. Over all the quality is okay. If the button holes stretch out that will pretty much ruin the shirt...so it all hinges on that over time.
# Read more
# --------------------------------------------------------------------------------
# Title: 5.0 out of 5 stars
# Great shirt
# Rating: 5.0 out of 5 stars
# Content: I bought this shirt for my son in law. The quality and material are great! My son in law loved it!
# Read more
# --------------------------------------------------------------------------------
# Title: 5.0 out of 5 stars
# Comfortable
# Rating: 5.0 out of 5 stars
# Content: I bought this shirt for my boyfriend’s birthday gift. He’s extremely picky when it comes to clothing. He is 6”3’ and he is pretty muscular which when buying shirts for him I need to make sure they are an appropriate length. This shirt fits him extremely well and is very flattering on his figure. When washing it didn’t shrink at all. The material is not too thin but not to thick, it is pretty breathable. The holes in the shirt aren’t big at all, which means you don’t need an under shirt underneath. For the price and quality of the product I do see it is fair.
# Read more
# --------------------------------------------------------------------------------
# Title: 5.0 out of 5 stars
# Great fit!
# Rating: 5.0 out of 5 stars
# Content: Bought for my husband to wear on our honeymoon & it was the perfect shirt! Lightweight & good quality. Washed on delicates and still looks great.
# Read more
# --------------------------------------------------------------------------------
# Title: 3.0 out of 5 stars
# Breathable material, size run small
# Rating: 3.0 out of 5 stars
# Content: Advice: GO for a extra size.Hello, I always have a sweet spot for this brand, however with this shirt unfortunately the size run small, even when it's my size. I am not fit (have belly) but this one feels a little tight to the body, it is breathable and stretch but tight. The colour is fantastic very pretty. The fabric is comfy but thin so watch out for that.One thing that dislike in this one is the neck, the design is like too high, like going all the way to the back.
# Read more
# --------------------------------------------------------------------------------
# Title: 5.0 out of 5 stars
# Great fit
# Rating: 5.0 out of 5 stars
# Content: Got this as a gift they loved the material
# Read more
# --------------------------------------------------------------------------------
# Title: Chemise
# Rating: 5.0 out of 5 stars
# Content: Super belle, bonne qualité 👍
# Read more
# --------------------------------------------------------------------------------
# Title: Excelente
# Rating: 5.0 out of 5 stars
# Content: Muy buena calidad, talla exacta, escelente compra!
# Read more
# --------------------------------------------------------------------------------
# Title: Mala calidad
# Rating: 1.0 out of 5 stars
# Content: Muy pobre su elaboración
# Read more
# --------------------------------------------------------------------------------
# Title: Knit shirts was excellent
# Rating: 5.0 out of 5 stars
# Content: It’s a best product and it arrived on time
# Read more
# --------------------------------------------------------------------------------
# Title: Not knit
# Rating: 1.0 out of 5 stars
# Content: Shirt not knit as advertised
# Read more
# --------------------------------------------------------------------------------
